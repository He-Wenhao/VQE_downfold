# %%
import matplotlib.pyplot as plt
import numpy as np

# Open the file and read its contents into a string
with open('opt_rounds_data.txt', 'r') as file:
    data = file.read()

l=100000000
# Now 'data' contains the contents of 'opt_data.txt' as a string
#print(data)

# Parsing the data
total_energies = []
entropies = []

# Splitting the data into lines and extracting numbers
for line in data.strip().split("\n"):
    parts = line.split()
    if len(parts) < 2:
        break
    #print(parts)
    #energy = float(parts[0].split(":")[1].strip())
    #entropy = float(parts[1].split(":")[1].strip())
    energy = float(parts[0])
    entropy = float(parts[1])
    total_energies.append(energy)
    entropies.append(entropy)

# Plotting the data
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Step')
ax1.set_ylabel('Total Energy', color=color)
ax1.plot(total_energies[:l], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Entropy', color=color)
ax2.plot(entropies[:l], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.title('Total Energy and Entropy over Optimization Steps')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Open the file and read its contents into a string
with open('opt_rounds_data.txt', 'r') as file:
    data = file.read()

l=100
# Now 'data' contains the contents of 'opt_data.txt' as a string
#print(data)

# Parsing the data
total_energies = []
entropies = []

# Splitting the data into lines and extracting numbers
for line in data.strip().split("\n"):
    parts = line.split(";")
    energy = float(parts[0].split(":")[1].strip())
    entropy = float(parts[1].split(":")[1].strip())
    total_energies.append(energy)
    entropies.append(entropy)

# Plotting the data
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Step')
ax1.set_ylabel('Total Energy', color=color)
ax1.plot(total_energies[:l], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Entropy', color=color)
ax2.plot(entropies[:l], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.title('Total Energy and Entropy over Optimization Steps')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 19
#      17 for line in data.strip().split("\n"):
#      18     parts = line.split(";")
# ---> 19     energy = float(parts[0].split(":")[1].strip())
#      20     entropy = float(parts[1].split(":")[1].strip())
#      21     total_energies.append(energy)
#
# IndexError: list index out of range
